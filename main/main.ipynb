# %% [markdown]
# # Main Script

# %%
# %matplotlib inline
# %run "../functions/functions"

# %%
from fastai import *
from fastai.vision import*

# %% [markdown]
# ## Define Classes and Download Images

# %%
classes = ['sea', 'river']

# %%
path = Path('../data/Otters')

# %%
downloadImages(path, "sea", "urls_sea.txt")

# %%
downloadImages(path, "river", "urls_river.txt")
# Out:
#   File "<ipython-input-29-42f7422e3d5e>", line 1
#     downloadImages(path, , "urls_sea.txt")
#                          ^
# SyntaxError: invalid syntax

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size = 500)

# %% [markdown]
# ## View Data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct = 0.2,
                                 ds_tfms = get_transforms(), size = 64, num_workers=0).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['river', 'sea']

# %%
data.show_batch(rows = 3, figsize = (3, 4))

# %%
learn = cnn_learner(data, models.resnet34, metrics = error_rate)
# Out:
# C:\Users\ChrisLai\Anaconda3\envs\myenv\lib\site-packages\fastai\vision\learner.py:106: UserWarning: `create_cnn` is deprecated and is now named `cnn_learner`.
#   warn("`create_cnn` is deprecated and is now named `cnn_learner`.")
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to C:\Users\ChrisLai/.cache\torch\checkpoints\resnet34-333f7ec4.pth
# 100%|█████████████████████████████████████████████████████████████████| 87306240/87306240 [00:12<00:00, 7006368.31it/s]
